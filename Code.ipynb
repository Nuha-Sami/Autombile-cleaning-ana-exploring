# %%
#Task 1: Data Preparation
# "You will start by loading the CSV data from the file (using appropriate pandas functions) and checking whether the loaded data is equivalent to the data in the source CSV file.
# Then, you need to clean the data by using the knowledge we taught in the lectures. You need to deal with all the potential issues/errors in the data appropriately (such as: typos, extra whitespaces, sanity checks for impossible values, and missing values etc). "

# Please structure code as follows: 
# always provide one line of comments to explain the purpose of the code, e.g. load the data, checking the equivalent to original data, checking typos (do this for each other types of errors)
# loading the CSV data from the file and assign it to the Automobile variable
Automobile_p = 'Automobile.csv'
# import the panda's package
import pandas as pd
#use the read-csv function which contains 3 arguments this line is the dataframe
Automobile= pd.read_csv(Automobile_p, sep='#', decimal='.', header= None, names=['Symboling','Normalized losses','Make','Fuel type','Aspiration','Number of doors','Body style','Drive wheels','Engine Location','Wheel base','Length','Width','Height','Curb weight','Engine type','Num of cylinders','Engine size','Fuel System','Bore','Stroke','Compression ratio','Horse power','Peak RPM','City MPG','HighWay MPG','Price'])
# use this code to dispaly all the columns' types 
Automobile.dtypes
# use the head function to display the first five observations to ensure the the data has been loaded properly.
Automobile.head()
# use the head function to display the last five observations to ensure the the data has been loaded properly.
Automobile.tail()
# to make sure of the colmuns of the dataset
Automobile.columns
# to display the size of the columns and rows of the dataset to check if the data is complete or not
x=Automobile[['Symboling','Normalized losses','Make','Fuel type','Aspiration','Number of doors','Body style','Drive wheels','Engine Location','Wheel base','Length','Width','Height','Curb weight','Engine type','Num of cylinders','Engine size','Fuel System','Bore','Stroke','Compression ratio','Horse power','Peak RPM','City MPG','HighWay MPG','Price']]
x.shape
# to display the Symboling column and clean it 
Automobile ['Symboling']
# to display the Symboling columns value's frequency 
Automobile['Symboling'].value_counts()
# to check the impossible values in the column
check= -3<= 'Symboling' <= +3
print check
# to replace the impossible value 4 with 0 as the highest frequency for Symboling Column
Automobile['Symboling']=Automobile['Symboling'].replace(4,0)
# to make sure that the valuse has been change from 4 to 0.
Automobile[Automobile['Symboling'].between(-3,3)]
# to display the order of the column to check if all the values are in the range 
Automobile['Symboling'].sort_values()
# to check the minimum value of the column
Automobile['Symboling'].min()
# to check the maximum value of the column
Automobile['Symboling'].max()
# to display the frequecy of the column again and ensure that the changes has been done
Automobile['Symboling'].value_counts()
# to display the Symboling columns value's frequency 
Automobile['Normalized losses'].value_counts()
# to display the order of the column to check if all the values are in the range 
Automobile['Normalized losses'].sort_values()
# this function is return true for the Null value and False for the cells that have value
Automobile['Normalized losses'].isnull()
# this function is used to drop all the null values in that column
Automobile['Normalized losses'].dropna()
# this function is used to display the column's size 
Automobile['Normalized losses'].shape
# to sort the value according to the index
Automobile.sort_index(by='Normalized losses')
# the package that is used for exploration and especially for the visualization 
import matplotlib.pyplot as plt 
# import the package that help in assigning null valuse in a column
import numpy as np
# used the density graph to display the distrbustion of the values in that column 
Automobile['Normalized losses'].plot(kind='density')
# the fillna function is used to fill the null value with the median values by using Median () function
Automobile['Normalized losses'].fillna(Automobile['Normalized losses'].median(axis=0),inplace=True)
# to display the size of that column
Automobile['Normalized losses'].shape
# to display the order of the column to check if all the values are in the range
Automobile['Normalized losses'].sort_values()
#to check if all of the values are in the range of that column
check1= 65.0<= 'Normalized losses' <= 256.0
print check1
Automobile[Automobile['Normalized losses'].between(65,256)]
# loc function is used to access a specific data which are 25 and re-assign them with 0
Automobile.loc[Automobile['Normalized losses'] ==25.0,'Normalized losses']=np.nan
# used the density graph to display the distrbustion of the values in that column
Automobile['Normalized losses'].plot(kind='density')
# to display the order of the column to check if all the values are in the range
Automobile['Normalized losses'].sort_values()
# the fillna() function is used to fill the null value with the median values by using Median () function
Automobile['Normalized losses'].fillna(Automobile['Normalized losses'].median(axis=0),inplace=True)
# to display the order of the column to check if all the values are in the range
Automobile['Normalized losses'].sort_values()
#to display the minimun value
Automobile['Normalized losses'].min()
#to display the maximum value
Automobile['Normalized losses'].max()
# to display the Make's columns value's frequency 
Automobile['Make'].value_counts()
# strip function is used to remove the extra white spaces
Automobile['Make']=Automobile['Make'].str.strip()
# to replace the word with the typo or mistake problem with the correct one
Automobile['Make'].replace('vol00112ov','volvo', inplace=True)
# lower() function is used to makes all the upper case in the column to the lower case
Automobile['Make']=Automobile['Make'].str.lower()
# to display the frequecy of the column again and ensure that the changes has been done
Automobile['Make'].value_counts()
# to display the Fuel types's columns value's frequency 
Automobile['Fuel type'].value_counts()
# strip function is used to remove the extra white spaces
Automobile['Fuel type']=Automobile['Fuel type'].str.strip()
# lower() function is used to makes all the upper case in the column to the lower case
Automobile['Fuel type']=Automobile['Fuel type'].str.lower()
# to display the frequecy of the column again and ensure that the changes has been done
Automobile['Fuel type'].value_counts()
#to display the Aspiration columns value's frequency 
Automobile['Aspiration'].value_counts()
# strip function is used to remove the extra white spaces
Automobile['Aspiration']=Automobile['Aspiration'].str.strip()
# lower() function is used to makes all the upper case in the column to the lower case
Automobile['Aspiration']=Automobile['Aspiration'].str.lower()
# to replace the word with the typo or mistake problem with the correct one
Automobile['Aspiration'].replace('turrrrbo','turbo', inplace=True)
# to display the frequecy of the column again and ensure that the changes has been done
Automobile['Aspiration'].value_counts()
# to display the Num of doors' columns value's frequency 
Automobile['Number of doors'].value_counts()
# strip function is used to remove the extra white spaces
Automobile['Number of doors']=Automobile['Number of doors'].str.strip()
# lower() function is used to makes all the upper case in the column to the lower case
Automobile['Number of doors']=Automobile['Number of doors'].str.lower()
# to replace the word with the typo or mistake problem with the correct one
Automobile['Number of doors'].replace('fourR','four', inplace=True)
# to replace the word with the typo or mistake problem with the correct one
Automobile['Number of doors'].replace('fourr','four', inplace=True)
# to display the order of the column to check if all the values are in the range
Automobile['Number of doors'].sort_values()
# dropna function is used to drop all the null values in the column
Automobile['Number of doors'].dropna()
# to visualize the column in the Pie chart to discover the majority 
Automobile['Number of doors'].value_counts().plot(kind='pie', autopct='%.2f')
#fillna is used to fill the null values with four as it the highest frequency than two 
Automobile['Number of doors']=Automobile['Number of doors'].fillna('four')
# to display the frequecy of the column again and ensure that the changes has been done
Automobile['Number of doors'].value_counts()
# to display the Body style' columns value's frequency 
Automobile['Body style'].value_counts()
# strip function is used to remove the extra white spaces
Automobile['Body style']=Automobile['Body style'].str.strip()
# lower() function is used to makes all the upper case in the column to the lower case
Automobile['Body style']=Automobile['Body style'].str.lower()
# to display the frequecy of the column again and ensure that the changes has been done
Automobile['Body style'].value_counts()
# to display the Drive wheels' columns value's frequency 
Automobile['Drive wheels'].value_counts()
# strip function is used to remove the extra white spaces
Automobile['Drive wheels']=Automobile['Drive wheels'].str.strip()
# lower() function is used to makes all the upper case in the column to the lower case
Automobile['Drive wheels']=Automobile['Drive wheels'].str.lower()
# to display the frequecy of the column again and ensure that the changes has been done
Automobile['Drive wheels'].value_counts()
# to display the Engine location' columns value's frequency 
Automobile['Engine Location'].value_counts()
# strip function is used to remove the extra white spaces
Automobile['Engine Location']=Automobile['Engine Location'].str.strip()
# lower() function is used to makes all the upper case in the column to the lower case
Automobile['Engine Location']=Automobile['Engine Location'].str.lower()
# to display the frequecy of the column again and ensure that the changes has been done
Automobile['Engine Location'].value_counts()
# to display the Wheel base value's frequency 
Automobile['Wheel base'].value_counts()
# to display the order of the column to check if all the values are in the range
Automobile['Wheel base'].sort_values()
# to display the Length' columns value's frequency 
Automobile['Length'].value_counts()
# to display the order of the column to check if all the values are in the range
Automobile['Length'].sort_values()
# to display the minimum value
Automobile['Length'].min()
# to display the maximum value
Automobile['Length'].max()
# to display the Width' columns value's frequency 
Automobile['Width'].value_counts()
# to display the order of the column to check if all the values are in the range
Automobile['Width'].sort_values()
# to display the minimum value
Automobile['Width'].min()
# to display the maximum value
Automobile['Width'].max()
# to visualize the column in the Plot chart to discover if there is an outlier
Automobile['Width'].plot(kind='box')
# to display the Height' columns value's frequency 
Automobile['Height'].value_counts()
# to display the ordere of the column to check if there are values out of the range.
Automobile['Height'].sort_values()
# to display the minimum value
Automobile['Height'].min()
# to display the maximum value
Automobile['Height'].max()
# to display the Curb weight' columns value's frequency 
Automobile['Curb weight'].value_counts()
# to display the order of the column to check if all the values are in the range
Automobile['Curb weight'].sort_values()
# to visualize the column in the Plot chart to discover if there is an outlier
Automobile['Curb weight'].plot(kind='box')
# to display the Engine type' columns value's frequency 
Automobile['Engine type'].value_counts()
# strip function is used to remove the extra white spaces
Automobile['Engine type']=Automobile['Engine type'].str.strip()
# lower() function is used to makes all the upper case in the column to the lower case
Automobile['Engine type']=Automobile['Engine type'].str.lower()
# to display the frequecy of the column again and ensure that the changes has been done
Automobile['Engine type'].value_counts()
# to display the Num od cylinders columns value's frequency
Automobile['Num of cylinders'].value_counts()
# to visualize the column to discover if there are outliers.
Automobile.boxplot(column='Symboling',by='Num of cylinders')
# strip function is used to remove the extra white spaces
Automobile['Num of cylinders']=Automobile['Num of cylinders'].str.strip()
# lower() function is used to makes all the upper case in the column to the lower case
Automobile['Num of cylinders']=Automobile['Num of cylinders'].str.lower()
# to display the frequecy of the column again and ensure that the changes has been done
Automobile['Num of cylinders'].value_counts()
# to display the Engine size' columns value's frequency
Automobile['Engine size'].value_counts()
# to display the order of the column to check if all the values are in the range
Automobile['Engine size'].sort_values()
# to display the Fuel system' columns value's frequency
Automobile['Fuel System'].value_counts()
# to display the order of the column to check if all the values are in the range
Automobile['Fuel System'].sort_values()
# strip function is used to remove the extra white spaces
Automobile['Fuel System']=Automobile['Fuel System'].str.strip()
# lower() function is used to makes all the upper case in the column to the lower case
Automobile['Fuel System']=Automobile['Fuel System'].str.lower()
# to display the frequecy of the column again and ensure that the changes has been done
Automobile['Fuel System'].value_counts()
# to display the Bore' columns value's frequency
Automobile['Bore'].value_counts()
# to display the order of the column to check if all the values are in the range
Automobile['Bore'].sort_values()
# dropna is used to drop all the null values in the column
Automobile['Bore'].dropna()
# used the density graph to display the distrbustion of the values in that column 
Automobile['Bore'].plot(kind='density')
# the fillna() function is used to fill the null value with the median values by using Median () function
Automobile['Bore'].fillna(Automobile['Bore'].mean(axis=0),inplace=True)
# to check the size of the column
Automobile['Bore'].shape
# to display the order of the column to check if all the values are in the range
Automobile['Bore'].sort_values()
# to display the Bore' columns value's frequency
Automobile['Stroke'].value_counts()
# to display the order of the column to check if all the values are in the range
Automobile['Stroke'].sort_values()
# dropna function is used to drop all the null values in the column
Automobile['Stroke'].dropna()
# used the density graph to display the distrbustion of the values in that column 
Automobile['Stroke'].plot(kind='density')
# the fillna() function is used to fill the null value with the median values by using Median () function
Automobile['Stroke'].fillna(Automobile['Stroke'].median(axis=0),inplace=True)
# to figure out the size of the column
Automobile['Stroke'].shape
# to display the order of the column to check if all the values are in the range
Automobile['Stroke'].sort_values()
# to display the Compression ratio' columns value's frequency
Automobile['Compression ratio'].value_counts()
# to display the order of the column to check if all the values are in the range
Automobile['Compression ratio'].sort_values()
# to visualize the column in the Plot and histogram chart to discover if there is an outlier
Automobile['Compression ratio'].plot(kind='hist',bins=10)
Automobile['Compression ratio'].plot(kind='box')
# to display the Horse power' columns value's frequency
Automobile['Horse power'].value_counts()
# to display the order of the column to check if all the values are in the range
Automobile['Horse power'].sort_values()
# dropna function is used to drop all the null values in the column
Automobile['Horse power'].dropna()
# to visualize the column in the Plot chart to discover if there is an outlier
Automobile['Horse power'].plot(kind='density')
# the fillna() function is used to fill the null value with the median values by using Median () function
Automobile['Horse power'].fillna(Automobile['Horse power'].median(axis=0), inplace=True)
# to display the order of the column to check if all the values are in the range
Automobile['Horse power'].sort_values()
# to display the peak RPM' columns value's frequency
Automobile['Peak RPM'].value_counts()
# to display the order of the column to check if all the values are in the range
Automobile['Peak RPM'].sort_values()
# dropna function is used to drop all the null values in the column
Automobile['Peak RPM'].dropna()
# to visualize the column in the Plot chart to discover if there is an outlier
Automobile['Peak RPM'].plot(kind='density')
# the fillna() function is used to fill the null value with the median values by using Median () function
Automobile['Peak RPM'].fillna(Automobile['Peak RPM'].median(axis=0),inplace=True)
Automobile['Peak RPM'].shape
# to display the order of the column to check if all the values are in the range
Automobile['Peak RPM'].sort_values()
# to display the city MPG' columns value's frequency
Automobile['City MPG'].value_counts()
# to display the order of the column to check if all the values are in the range
Automobile['City MPG'].sort_values()
#to check the minimum value
Automobile['City MPG'].min()
#to check the maximum value
Automobile['City MPG'].max() 
# to display the HighWay MPG columns value's frequency
Automobile['HighWay MPG'].value_counts()
# to display the order of the column to check if all the values are in the range
Automobile['HighWay MPG'].sort_values()
#to check the minimum value
Automobile['HighWay MPG'].min()
#to check the maximum value
Automobile['HighWay MPG'].max()
# to display the price columns value's frequency
Automobile['Price'].value_counts()
# to display the order of the column to check if all the values are in the range
Automobile['Price'].sort_values()
# dropna function is used to drop all the null values in the column
Automobile['Price'].dropna()
# # used the density graph to display the distrbustion of the values in that column 
Automobile['Price'].plot(kind='density')
# the fillna() function is used to fill the null value with the median values by using Median () function
Automobile['Price'].fillna(Automobile['Price'].median(axis=0), inplace=True)
# to display the order of the column to check if all the values are in the range
Automobile['Price'].sort_values()
#to check if there are values out of the range 
check1= 5118 <= 'Price' <= 45400
print check1
# loc function is used to access a specific data which are 0 and re-assign them with 0
Automobile.loc[Automobile['Price'] ==0,'Price']=np.nan
# to display the order of the column to check if all the values are in the range
Automobile['Price'].sort_values()
# dropna function is used to drop all the null values in the column
Automobile['Price'].dropna()
# the fillna() function is used to fill the null value with the mean values by using Median () function
Automobile['Price'].fillna(Automobile['Price'].mean(axis=0),inplace=True)
# to display the order of the column to check if all the values are in the range
Automobile['Price'].sort_values()
# to check the minumnm value
Automobile['Price'].min()
# to check the maximum value
Automobile['Price'].max()
# Out:
# False
# C:\Users\nhawi\Downloads\Anaconda2\lib\site-packages\ipykernel_launcher.py:54: FutureWarning: by argument to sort_index is deprecated, please use .sort_values(by=...)
# False
# False
# 45400.0

# %%
# Task 2: Data Exploration
# 1. Choose 1 column with nominal values, 1 column with ordinal Values, and 1 column with numerical values


#Code goes after this line

# to viusalize the nominal column which is Engine Location
Automobile['Engine Location'].value_counts().plot(kind='pie', autopct='%.1f')

#to viusalize the ordinal column which is Symboling
Automobile['Symboling'].plot(kind='hist', bins=5)
plt.title('Insurance risk rating - 3: hight risk ; -3: indicates safe ')
plt.xlabel('Symboling')
plt.show()

# to viusalize the Interval column which is Height
Automobile['Height'].plot(kind='box')

# %%
# Task 2: Data Exploration
# 2. Explore the relationships between columns; at least 3 visualisations with plausible hypothesis

#Code goes after this line
# the scatter plot graph will show the relationship between the price and the hourse power
Automobile.plot(kind='scatter',x=21,y=25)
plt.show()

# the Hexbin graph will show the relationship between the length and the width
Automobile.plot(kind='hexbin',x=10,y=11,gridsize=10)
plt.xlabel('Length')

# the Hexbin graph will show the relationship between the Engine Size and the City MPG
Automobile.plot(kind='hexbin',x=16,y=23,gridsize=10)
plt.xlabel('Engine size')
# Out:
# Text(0.5,0,'Engine size')

# %%
# Task 2: Data Exploration
# 3. Scatter matrix for all numerical columns

#Code goes after this line

# the new dataframe that is use to incluse all the numrical columns 
Automobile_num= pd.read_csv(Automobile_p , sep='#', decimal='.', header= None, names=['Symboling','Normalized losses','Wheel base','Length','Width','Height','Curb weight','Engine size','Bore','Stroke','Compression ratio','Horse power','Peak RPM','City MPG','HighWay MPG','Price'])

# import the sactter matrix gragh from the panda's library to enable the scattermatrix to be displayed
from pandas.tools.plotting import scatter_matrix
scatter_matrix(Automobile_num,alpha=0.2,figsize=(16,16),diagonal='hist')
plt.show()
# Out:
# C:\Users\nhawi\Downloads\Anaconda2\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   # This is added back by InteractiveShellApp.init_path()
